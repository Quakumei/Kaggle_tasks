# %% [markdown]
# <a href="https://colab.research.google.com/github/Quakumei/Kaggle_tasks/blob/master/CarykhsVideoShortener.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/carykh/jumpcutter/
# !pip install -r jumpcutter/requirements.txt
# !sudo apt-get install ffmpeg
# !pip install pytube3
# Out:
# Cloning into 'jumpcutter'...
# remote: Enumerating objects: 50, done.
# remote: Total 50 (delta 0), reused 0 (delta 0), pack-reused 50
# Unpacking objects: 100% (50/50), done.

# %%
# Добавьте файл в папку jumpcutter и переименуйте в input.mkv, 
# если используете другие имя\формат, не забудьте поменять это в команде.

# %%
# !cd jumpcutter && python jumpcutter.py --input_file input.mkv  --output_file go.avi --sounded_speed 2 --silent_speed 9 --frame_margin 2
# Out:
# Input #0, matroska,webm, from 'input.mkv':
#   Metadata:
#     ENCODER         : Lavf58.29.100
#   Duration: 00:01:57.57, start: 0.000000, bitrate: 2168 kb/s
#     Stream #0:0: Video: h264 (High), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 30 fps, 30 tbr, 1k tbn, 60 tbc (default)
#     Metadata:
#       DURATION        : 00:01:57.566000000
#     Stream #0:1: Audio: aac (LC), 44100 Hz, stereo, fltp (default)
#     Metadata:
#       title           : simple_aac
#       DURATION        : 00:01:57.377000000
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5614b18a2000] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'TEMP/frame%06d.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
# ...
